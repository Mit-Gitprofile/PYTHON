# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time


service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
driver.get(f"https://www.flipkart.com/")
time.sleep(2)

elem = driver.find_element(By.CLASS_NAME,"Pke_EE")
elem.send_keys(Keys.RETURN)
time.sleep(2)

search="Macbooks"
elem = driver.find_element(By.CLASS_NAME,"Pke_EE")
elem.send_keys(search)
time.sleep(2)

elem = driver.find_element(By.CLASS_NAME,"Pke_EE")
elem.send_keys(Keys.RETURN)
time.sleep(2)

driver.save_screenshot('C://Users/HP/OneDrive/Pictures/Screenshots/screenshot_1.png')


import requests
from bs4 import BeautifulSoup
import pandas as pd

Title=[]
Prices=[]

url="https://www.flipkart.com/search?q=Macbooks&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

request=requests.get(url)
# print(request.status_code)

soup=BeautifulSoup(request.text,"html.parser")
box=soup.find("div",class_="DOjaWF gdgoEp")

title=box.find_all("div",class_="KzDlHZ")
for i in title:
    tt=i.text
    Title.append(tt)
for i in Title:
    print(i)
print(len(Title))

price=box.find_all("div",class_="Nx9bqj _4b5DiR")
for i in price:
    prc=i.text
    Prices.append(prc)
for i in Prices:
    print(i)
print(len(Prices))

driver.quit()
# Out:
# Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/Mac OS Monterey) MLXY3HN/A
# Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/Mac OS Monterey) MLY13HN/A
# Apple 2020 Macbook Air Apple M1 - (8 GB/256 GB SSD/Mac OS Big Sur) MGN93HN/A
# Apple 2020 Macbook Air Apple M1 - (8 GB/256 GB SSD/Mac OS Big Sur) MGND3HN/A
# Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/Mac OS Monterey) MLY33HN/A
# Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/Mac OS Monterey) MLXW3HN/A
# Apple MacBook AIR Apple M2 - (16 GB/256 GB SSD/macOS Sequoia) MC7X4HN/A
# Apple MacBook AIR Apple M2 - (16 GB/256 GB SSD/macOS Sequoia) MC7V4HN/A
# Apple MacBook Air Apple M3 - (8 GB/256 GB SSD/macOS Sonoma) MRXT3HN/A
# Apple MacBook AIR Apple M2 - (16 GB/256 GB SSD/macOS Sequoia) MC7U4HN/A
# Apple MacBook AIR Apple M2 - (8 GB/512 GB SSD/Mac OS Monterey) MLXX3HN/A
# Apple MacBook Air Apple M3 - (8 GB/512 GB SSD/macOS Sonoma) MRXP3HN/A
# Apple MacBook AIR Apple M2 - (8 GB/512 GB SSD/Mac OS Monterey) MLY03HN/A
# Apple MacBook AIR Apple M2 - (8 GB/512 GB SSD/Mac OS Monterey) MLY43HN/A
# Apple MacBook Air Apple M3 - (16 GB/512 GB SSD/macOS Sonoma) MXCV3HN/A
# Apple MacBook Air Apple M3 - (8 GB/256 GB SSD/macOS Sonoma) MRYU3HN/A
# Apple MacBook Pro Apple M3 - (8 GB/512 GB SSD/macOS Sonoma) MTL73HN/A
# Apple MacBook Pro Apple M3 - (8 GB/1 TB SSD/macOS Sonoma) MTL83HN/A
# Apple MacBook Air Apple M3 - (16 GB/512 GB SSD/macOS Sonoma) MXD43HN/A
# Apple MacBook Air Apple M3 - (16 GB/512 GB SSD/macOS Sonoma) MXCR3HN/A
# Apple Macbook Air Apple M2 - (8 GB/256 GB SSD/macOS Ventura) MQKR3HN/A
# Apple MacBook Pro Apple M3 - (8 GB/1 TB SSD/macOS Sonoma) MR7K3HN/A
# Apple MacBook Air Apple M1 - (8 GB/512 GB SSD/Mac OS Big Sur) Z12400092
# Apple MacBook Pro Apple M3 Max - (48 GB/1 TB SSD/macOS Sonoma) MUW63HN/A
# 24
# ₹88,449
# ₹99,899
# ₹99,900
# ₹99,900
# ₹72,990
# ₹95,699
# ₹99,899
# ₹99,899
# ₹96,049
# ₹94,249
# ₹98,199
# ₹1,13,990
# ₹1,00,990
# ₹83,990
# ₹1,34,900
# ₹1,24,900
# ₹1,36,990
# ₹1,39,990
# ₹1,54,900
# ₹1,34,900
# ₹1,24,900
# ₹1,54,990
# ₹1,10,900
# ₹3,45,990
# 24

# %% [markdown]
# Screenshot take from current link

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time


service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
driver.get(f"https://www.flipkart.com/")
time.sleep(2)

elem = driver.find_element(By.CLASS_NAME,"Pke_EE")
elem.send_keys(Keys.RETURN)
time.sleep(2)

search="Mobiles"
elem = driver.find_element(By.CLASS_NAME,"Pke_EE")
elem.send_keys(search)
time.sleep(2)

elem = driver.find_element(By.CLASS_NAME,"Pke_EE")
elem.send_keys(Keys.RETURN)
time.sleep(2)

driver.save_screenshot('C://Users/HP/OneDrive/Pictures/Screenshots/screenshot_1.png')

driver.quit()
