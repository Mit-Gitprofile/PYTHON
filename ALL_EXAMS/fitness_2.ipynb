# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time

url="https://www.health.harvard.edu/category/staying-healthy"

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
driver.get(url)
time.sleep(0)
Path=os.path.join(os.getcwd(),'healthdata_1.png')
driver.save_screenshot(Path)

Title=[]
Description=[]
Prices=[]
Image=[]

request=requests.get(url)
print(request.status_code)
soup=BeautifulSoup(request.text,"html.parser")

print("\n\nlink:-https://www.health.harvard.edu/category/staying-healthy")
print("---------------------------------------------")
print("Find All Title Name:-")
print("---------------------------------------------")
title=soup.find_all("p",class_="heading-subtle")
for i in title:
    tt=i.text
    Title.append(tt)
for i in Title:
    print(i)

print("\n\n---------------------------------------------")
print("Find All Title Description:-")
print("---------------------------------------------")
description=soup.find_all("div",class_="flex flex-col")
for i in description:
    des=i.h3.text
    Description.append(des)
for i in Description:
    print(i)

print("\n\n---------------------------------------------")
print("Find All Title Links:-")
print("---------------------------------------------")
price = soup.find_all("a", class_="article-card")
for i in price:
    prc = i.get('href')
    Prices.append(prc)
for prc in Prices:
    print(prc)


print("\n\n---------------------------------------------")
print("Find All Images:-")
print("---------------------------------------------")
img = soup.find_all("a", class_="article-card")
for i in img:
    mg = i.img['src']
    Image.append(mg)
for prc in Image:
    print(prc)
        
dataframe=pd.DataFrame({"Title":Title,"description":Description,"link":Prices,"Images":Image,})

dataframe.to_csv("data.csv")
# Out:
# 200
#
#
# link:-https://www.health.harvard.edu/category/staying-healthy
# ---------------------------------------------
# Find All Title Name:-
# ---------------------------------------------
# Staying Healthy
# Exercise & Fitness
# Nutrition
# Staying Healthy
# Exercise & Fitness
# Nutrition
# Exercise & Fitness
# Diseases & Conditions
# Staying Healthy
# Nutrition
# Exercise & Fitness
# Heart Health
#
#
# ---------------------------------------------
# Find All Title Description:-
# ---------------------------------------------
# Do products that claim to stop snoring actually work?
# Chair yoga: Benefits of a mind-body practice without the risk of falling
# Low-carb foods: Nutritious choices for creating a sustainable diet that's lower in carbohydrates
# Walking the right way improves your balance
# Pilates: A good option for older adults?
# Calcium-rich foods: How to boost your intake of this important mineral
# Fitness face-off
# How your dentist could save your life
# Try this: The "old man" test
# Weighing protein powders
# Cold comfort
# Work stress linked to poor heart health
#
#
# ---------------------------------------------
# Find All Title Links:-
# ---------------------------------------------
# https://www.health.harvard.edu/staying-healthy/do-products-that-claim-to-stop-snoring-actually-work
# https://www.health.harvard.edu/exercise-and-fitness/chair-yoga-benefits-of-a-mind-body-practice-without-the-risk-of-falling
# https://www.health.harvard.edu/nutrition/low-carb-foods-nutritious-choices-for-creating-a-sustainable-diet-thats-lower-in-carbohydrates
# https://www.health.harvard.edu/staying-healthy/walking-the-right-way-improves-your-balance
# https://www.health.harvard.edu/exercise-and-fitness/pilates-a-good-option-for-older-adults
# https://www.health.harvard.edu/nutrition/calcium-rich-foods-how-to-boost-your-intake-of-this-important-mineral
# https://www.health.harvard.edu/exercise-and-fitness/fitness-face-off
# https://www.health.harvard.edu/diseases-and-conditions/how-your-dentist-could-save-your-life
# https://www.health.harvard.edu/staying-healthy/try-this-the-old-man-test
# https://www.health.harvard.edu/nutrition/weighing-protein-powders
# https://www.health.harvard.edu/exercise-and-fitness/cold-comfort
# https://www.health.harvard.edu/heart-health/work-stress-linked-to-poor-heart-health
#
#
# ---------------------------------------------
# Find All Images:-
# ---------------------------------------------
# https://domf5oio6qrcr.cloudfront.net/medialibrary/16347/conversions/gettyimages-2161037380-thumb.jpg
# https://domf5oio6qrcr.cloudfront.net/medialibrary/16341/conversions/gettyimages-1314539036-thumb.jpg
# https://domf5oio6qrcr.cloudfront.net/medialibrary/16339/conversions/gettyimages-1516943190-thumb.jpg
# https://domf5oio6qrcr.cloudfront.net/medialibrary/14277/conversions/346af349-a169-40f9-b94d-8720a14c0496-thumb.jpg
# https://domf5oio6qrcr.cloudfront.net/medialibrary/16326/conversions/gettyimages-1256523737-thumb.jpg
# https://domf5oio6qrcr.cloudfront.net/medialibrary/16311/conversions/gettyimages-1187993811-thumb.jpg
# https://domf5oio6qrcr.cloudfront.net/medialibrary/16089/conversions/p3-exercise-wl0224-gi1158622742-thumb.jpg
# https://domf5oio6qrcr.cloudfront.net/medialibrary/16092/conversions/p1-dentist-wl0224-gi1512069065-thumb.jpg
# https://domf5oio6qrcr.cloudfront.net/medialibrary/16096/conversions/p7-oldmantest-ml0225-gi2030449454-thumb.jpg
# https://domf5oio6qrcr.cloudfront.net/medialibrary/16099/conversions/p4-proteinpowder-ml0225-gi1015345458-thumb.jpg
# https://domf5oio6qrcr.cloudfront.net/medialibrary/16102/conversions/p1-skier-ml0225-gi1386353441-thumb.jpg
# https://domf5oio6qrcr.cloudfront.net/medialibrary/16104/conversions/p8-workstress-hh0225-gi1388795003-thumb.jpg
