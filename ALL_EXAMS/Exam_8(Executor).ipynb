# %%
# Executor #
#==========#

import os

print("\n=======================================================")
print("Executor - Command Line Utility and File System Manager")
print("=======================================================\n")
while True:

    print("===============================================")
    print("  ***   Chose an option:")
    print("===============================================")
    print("   1. File System Operations")
    print("   2. Execute Terminal Commands")
    print("   3. File Analysis With Higher-Order Functions")
    print("   4. Exit")
    print("===============================================\n")

    main_choise=int(input("Enter your choise:"))

    match main_choise:
        
        case 1:
            while True:
                print("  ***   File System Operations:")
                print("   1. Display Current Directory")
                print("   2. List Files and Directories")
                print("   3. Chenge Directory")
                print("   4. Create A Directory")
                print("   5. Remove A Directory")
                print("   6. Create A File")
                print("   7. Delete A File")
                print("   8. Back To Main Menu\n")

                File_choise=int(input("Enter Your Choise:"))
                match File_choise:
                    case 1:
                        path=os.getcwd()
                        print(f"Path: {path}\n")

                    case 2:
                        list=os.listdir()
                        print("``````````````````````````````````")
                        print(f"List Of File And Ditrectories:")
                        print("``````````````````````````````````")
                        for files in list:
                            print(f" - {files}")
                        print("``````````````````````````````````\n")
                        
                    case 3:
                        list=os.listdir()
                        print("``````````````````````````````````")
                        print(f"List Of File And Ditrectories:")
                        print("``````````````````````````````````")
                        for files in list:
                            print(f" - {files}")
                        print("``````````````````````````````````\n")

                        directory_name=input("Enter name To Chenge Directories:")
                        current=os.getcwd()
                        print(current)
                        chenge=os.chdir(current.join(directory_name))
                        print(f"Chenged:{chenge}")


                    case 8:
                        break
                        # Exit_choise=input("Do yoiu really want to exit? (yes/no) :")

                        # if(Exit_choise.lower()=="yes"):
                        #     print("Thank you for Using the Executor - Command Line Utility and \nFile System Manager .. Good Bye....")
                        #     break
                        # elif(Exit_choise.lower()=="no"):
                        #     print("Continue to programm....")
                        #     continue
                        # else:
                        #     print("\nEnter only yes or no ....\n")
                    
                    case _:
                        print("Invelid choise.....")


        case 2:
            pass

        case 3:
            pass

        case 4:
            break
            # Exit_choise=input("Do yoiu really want to exit? (yes/no) :")

            # if(Exit_choise.lower()=="yes"):
            #     print("Thank you for Using the Executor - Command Line Utility and \nFile System Manager .. Good Bye....")
            #     break
            # elif(Exit_choise.lower()=="no"):
            #     print("Continue to programm....")
            #     continue
            # else:
            #     print("\nEnter only yes or no ....\n")
        
        case _:
            print("Invelid choise.....")
# Out:
# =======================================================
# Executor - Command Line Utility and File System Manager
# =======================================================
#
# ===============================================
#   ***   Chose an option:
# ===============================================
#    1. File System Operations
#    2. Execute Terminal Commands
#    3. File Analysis With Higher-Order Functions
#    4. Exit
# ===============================================
#
#   ***   File System Operations:
#    1. Display Current Directory
#    2. List Files and Directories
#    3. Chenge Directory
#    4. Create A Directory
#    5. Remove A Directory
#    6. Create A File
#    7. Delete A File
#    8. Back To Main Menu
#
# Path: f:\Github_Desktop\PYTHON\ALL_EXAMS\my_folder
#
#   ***   File System Operations:
#    1. Display Current Directory
#    2. List Files and Directories
#    3. Chenge Directory
#    4. Create A Directory
#    5. Remove A Directory
#    6. Create A File
#    7. Delete A File
#    8. Back To Main Menu
#
# ===============================================
#   ***   Chose an option:
# ===============================================
#    1. File System Operations
#    2. Execute Terminal Commands
#    3. File Analysis With Higher-Order Functions
#    4. Exit
# ===============================================
