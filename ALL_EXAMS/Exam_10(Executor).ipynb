# %%
# Executor For OS_&_Subprocess-module #
#=====================================#

import os     #IMPORT OS LIBRARY

print("\n=======================================================")
print("Executor - Command Line Utility and File System Manager")
print("=======================================================\n")
while True:     #LOOP CONTINUE WHILW TRUE

    print("===============================================")
    print("  ***   Chose an option:")
    print("===============================================")
    print("   1. File System Operations")
    print("   2. Execute Terminal Commands")                        #OPSTIONS
    print("   3. File Analysis With Higher-Order Functions")
    print("   4. Exit")
    print("===============================================\n")

    main_choise=int(input("Enter your choise:"))       

    match main_choise:      #SWITCH CASE FOR MATCH CHOISES
    
    #CASE 1 FOR FILE SYSTEM OPERATIONS
        case 1:
            while True:
                print("  ***   File System Operations:")
                print("   1. Display Current Directory")
                print("   2. List Files and Directories")
                print("   3. Chenge Directory")
                print("   4. Go Back one Step To Current Directory")
                print("   5. Create A Directory")           
                print("   6. Remove A Directory")
                print("   7. Create A File")
                print("   8. Delete A File")
                print("   9. Back To Main Menu\n")

                File_choise=int(input("Enter Your Choise:"))
                match File_choise:
                # SHOW CURRENT PATH
                    case 1:
                        path=os.getcwd()
                        print(f"Directory Path: {path}\n")

                # DISPLAY ALL FILES AND DIRECTORIES 
                    case 2:
                        try:
                            list=os.listdir()
                            print("``````````````````````````````````")
                            print(f"List Of File And Directories:")
                            print("``````````````````````````````````")
                            for files in list:
                                print(f" - {files}")
                            print("``````````````````````````````````\n")

                        #IF FILE NOT FOUND GIVE BELOW ERROR
                        except FileNotFoundError:
                            print(f"Error: {directory_name} Dictionary Not Found ......")
                        
                #CHENGE DIRECTORY
                    case 3:
                        try:
                            directory_name=input("Enter name To Chenge Directories from all Directory list:")
                            current=os.getcwd()
                            print(f"Current directory: {os.getcwd()}")

                                #JOIN DIRECTORY NAME WITH CURRENT PATH
                            join_path=os.path.join(current,directory_name)
                            chenge=os.chdir(join_path)
                            print(f"Chenged directory: {os.getcwd()}")
                        
                            #HANDLE DIRECTORY NO FOUND ERROR
                        except FileNotFoundError:
                            print(f"Error: {directory_name} Dictionary Not Found in Current Folder...")

                #GO TO ONE STEP REVERCE FROM CURRENT DIRECTORY (LIKE CMD COMMAND [CD..])
                    case 4:
                        print("Go Back one Step To Current Directory:-\n")

                        print("Now Current Path:", os.getcwd())
                        chenge_path=input("Do You Want to go Beck To Previous Directory (yes/no):")

                        if chenge_path.lower()=="yes":
                            os.chdir("..")                  #GO REVERCE ONE STEP
                            print("Now Chenged Path:", os.getcwd())
                            
                        elif chenge_path.lower()=="no":
                            continue                        #CONTINUE PROGRAMM

                        else:
                            print("Enter only yes or no ...")
                        
                #CREATE A NEW DIRECTORY ON CURRENT PATH
                    case 5:
                        print("Create A Directory:-\n")

                        dir_name=input("Enter Name for create directory:")
                        dir_path=os.path.join(os.getcwd(),dir_name)  #JOIN DIRECTORY NAME ON CURRENT PATH
                        os.mkdir(dir_path)                           #MAKE NEW DIRECTORY

                        print(f"Directory Created Successfully With Name:'{dir_name}'")
                        path=os.getcwd()
                        print(f"Current Path: {path}\n")

                #REMOVE A DIRECTORY FROM CURRENT PATH
                    case 6:
                        try:
                            print("Remove A Directory:-")

                            dir_name_remove=input("Enter Name for remove directory:")

                            current_path=os.getcwd()
                            Del_path=os.path.join(current_path,dir_name_remove)    #JOIN DIRECTORY NAME ON CURRENT PATH

                            for files in os.listdir(Del_path):      #LIST OF FILES AND DIRECTORY IN CURRENT PATH

                                filepath=os.path.join(Del_path,files)
                                if os.path.isfile(filepath):            #DELETE ALL FILES
                                    os.remove(filepath)
                                    
                                elif os.path.isdir(filepath):           #DELETE ALL DIRECTOIES
                                    os.rmdir(files)

                            os.rmdir(dir_name_remove)                   #REMOVE SLECTED DIRECTORY 

                            print(f"Directory Removed Successfully With Name:'{dir_name_remove}'\n")

                        except FileNotFoundError:
                            print(f"Error: {dir_name_remove} Dictionary Not Found in Current Folder...")

                #CREATE A NEW FILE
                    case 7:
                        print("Create A File:-")

                        file_name=input("Enter Name for Create file:")

                        os.path.join(os.getcwd(),file_name)
                        file=open(file_name,"w+")                   #WRITE SOMETHING IN FILE FOR CREATE A NEW FILE
                        file.write(f"Hello\n this is {file_name} file...")
                        file.close()
                        
                        print(f"File '{file_name}' Created Succesfully..\n")

                #DELETE SELECTED FILE
                    case 8:
                        import os
                        try:
                            print("Delete A File:-")

                            file_name_remove=input("Enter Name for Remove file:")
                            
                            current=os.getcwd()
                            path=os.path.join(current,file_name_remove) #ADD FILE NAME IN CURRENT PATH
                            os.remove(path)                             #DELETE CURRENT PATH FILE
                            print(f"File '{file_name_remove}' Deleted Succesfully..\n")

                        except FileNotFoundError:
                            raise print(f"Error: {directory_name} File Not Found in Current Directory...")
                        
                #BREAK FROM FILE SYSTEM OPERATIONS
                    case 9:
                        break
                       
                    case _:
                        print("Invelid choise.....")


    #CASE 2 FOR COMMAND SYSTEM
        case 2:
            while True:
                print("  ***   Executr Terminal Commands:")
                print("   1. Run A Predefined Command (e.g.,pwd, ls)")
                print("   2. Run A Custom Command")
                print("   3. Back To Main Menu\n")

                Terminal_choise=int(input("Enter Your Choise:"))
                match Terminal_choise:
                #PREDEFIND COMMANDS OPERATIONS
                    case 1:
                        print("  Chose a Command:")     #COMMANDS
                        print("   1. pwd")
                        print("   2. ls")
                        print("   3. df -h\n")

                        inner_choise=int(input("Enter Your Choise:"))
                    
                    #GIVE CURRENT PATH
                        if inner_choise==1:
                            print(" Executing 'pwd'...")
                            path=os.getcwd()
                            print(f"Path is: {path}\n")

                    #GIVE LIST OF FILES AND DIRECTORIES
                        elif inner_choise==2:
                            print(" Executing 'ls'...")
                            list=os.listdir()
                            print("``````````````````````````````````")
                            print(f"List Of File And Directories:")
                            print("``````````````````````````````````")
                            for files in list:
                                print(f" - {files}")
                            print("``````````````````````````````````\n")

                    #GIVE MEMERY INFORMATION OF FILE MANAGER
                        elif inner_choise==3:
                            print(" Executing 'df -h'...")
                            data=os.popen('df -h')
                            result=data.read()
                            print(result)

                        else:
                            print("Wrong Choise...")

                #CUSTOM COMMAND OPERATIONS
                    case 2:   
                        import subprocess
                        print("  Chose a Command:")
                        print("   1. Help menu of ping")
                        print("   2. ping google.com")
                        print("   3. ping -n 10 google.com")
                        print("   4. ping -a google.com\n")


                        ping_choise=int(input("Enter Your Choise:"))
                        print("\n Running....\n")

                    #HELP MENU OF PING COMMANDS
                        if ping_choise==1:  
                            print("   1. Help menu of ping")
                            print("---------------------------------------------")
                            host="google.com"       #HOST NAME
                                
                            result=subprocess.run(["ping","/?"],stdout=subprocess.PIPE)     #DOCUMENTATIONS OF PING

                            print(result.stdout.decode())

                            print("---------------------------------------------")

                    #PING GOOGLE COMMAND
                        elif ping_choise==2:
                            print("    2. ping google.com")
                            print("---------------------------------------------")
                            host="google.com"       #HOST NAME
                               
                            result=subprocess.run(["ping",host],stdout=subprocess.PIPE)      #RUN PING COMMAND

                            print(result.stdout.decode())

                            print("---------------------------------------------")

                    #PING -N 10 GOOGLE COMMAND
                        elif ping_choise==3:
                            print("    3. ping -n 10 google.com")
                            print("---------------------------------------------")
                            host="google.com"       #HOST NAME

                            result=subprocess.run(["ping","-n","10",host],stdout=subprocess.PIPE)    #RUN PING COMMAND

                            print(result.stdout.decode())

                            print("---------------------------------------------")

                    #PING -A GOOGLE COMMAND
                        elif ping_choise==4:
                            print("    4. ping -a google.com ...")
                            print("---------------------------------------------")
                            
                            host="google.com"       #HOST NAME

                            result=subprocess.run(["ping","-a",host],stdout=subprocess.PIPE)     #RUN PING COMMAND

                            print(result.stdout.decode())

                            print("---------------------------------------------")

                #BREAK FROM EXECUTOR TERMINAL COMMANDS
                    case 3:
                       break

                    case _:
                        print("Invelid choise.....")

    #CASE 3 FOR HIGHER ORDER FUNCTIONS
        case 3:
            while True:
                print("  ***   File Analysis With Higher-order Functions:")
                print("   1. Sort Files By Name")
                print("   2. Filter Files by Extension")
                print("   3. calculate Total Size of Files in A dictionary")
                print("   4. Back To Main Menu\n")

                Analysis_choise=int(input("Enter Your Choise:"))
                match Analysis_choise:
                
                #SORT FILES BY NAME
                    case 1:
                        Sorted_name=input("Enter name to sorted files:")
                        
                        print(f"Sorted Files by name:'{Sorted_name}'")
                        print("-----------------------------------")
                        mainlist=[]
                        all_files=os.listdir()

                        for file in all_files:      #ADD ALL FILES IN MAINLIST
                            mainlist.append(file)

                        for data in mainlist:       #CHOOSE FILES ACCORDING CONDITION
                            if Sorted_name in data:
                                print(" - ",data)
                        print("-----------------------------------\n")
                        
                #SORT BY EXTENSIONS USING FILTER FUNCTION
                    case 2:
                        Sorted_ext=input("Enter file extension to filter by (e.g., .txt):")
                        
                        print(f"Sorted Files by Extensions:{Sorted_ext}")
                        print("-----------------------------------")
                        mainlist=os.listdir()
                        
                        def filter_functios(file):              #GIVE  ALL FILES TO FUNCTION
                            return file.endswith(Sorted_ext)        #RETURN FILE ONLY ENDSWITH GIVEN EXTENSION

                        Filter_by_extension=filter(filter_functios,mainlist)

                        for file in Filter_by_extension:    #PRINT ALL RETURN FILES
                            print(" - ",file)
                        print("-----------------------------------\n")

                #CALCULATE SIZE OF ALL FILES USING GETSIZE FUNCTION
                    case 3:
                        
                        print("-----------------------------------")
                        print(f"Calculating Total Size Of Files In The Current Directory...")
                        total_size=os.path.getsize(os.getcwd())   #GETSIZE OF CURRENT DIRECTORY
                        print(f"Total Size: {total_size} bytes.")
                        print("-----------------------------------\n")
                        
                #BREAK FROM HIGHER ORDER FUNCTION
                    case 4:
                       break

                    case _:
                        print("Invelid choise.....")

    #FOR EXIT FROM PROGRAMM
        case 4:
            Exit_choise=input("Do yoiu really want to exit? (yes/no) :")

            if(Exit_choise.lower()=="yes"):     #IF USER ENTETR YES PROGRAMM BREAK
                print("Thank you for Using the Executor - Command Line Utility and \nFile System Manager .. Good Bye....")
                break
            elif(Exit_choise.lower()=="no"):    #IF USER ENTETR no PROGRAMM CONTINUE
                print("Continue to programm....")
                continue
            else:
                print("\nEnter only yes or no ....\n")
        
        case _:
            print("Invelid choise.....")
# Out:
# ...
# Executor - Command Line Utility and File System Manager
# ...
#
# ...
#   ***   Chose an option:
# ...
#    1. File System Operations
#    2. Execute Terminal Commands
#    3. File Analysis With Higher-Order Functions
#    4. Exit
# ...
#
#   ***   File System Operations:
#    1. Display Current Directory
#    2. List Files and Directories
#    3. Chenge Directory
#    4. Go Back one Step To Current Directory
#    5. Create A Directory
#    6. Remove A Directory
#    7. Create A File
#    8. Delete A File
#    9. Back To Main Menu
#
# Directory Path: f:\Github_Desktop\PYTHON\ALL_EXAMS
#
#   ***   File System Operations:
#    1. Display Current Directory
#    2. List Files and Directories
#    3. Chenge Directory
#    4. Go Back one Step To Current Directory
#    5. Create A Directory
#    6. Remove A Directory
#    7. Create A File
#    8. Delete A File
#    9. Back To Main Menu
#
# ``````````````````````````````````
# List Of File And Directories:
# ``````````````````````````````````
# ...
