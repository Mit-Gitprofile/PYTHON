# %%
# Moduler And Packger #
#=====================#

#link - https://docs.google.com/document/d/1Dlbzg3hSDK40VxxmQqGcxm1nltDqP07k5qYxdSaTWrY/edit?tab=t.0

# Import libraries
from datetime import datetime
import math
import random
import string
import uuid
import os
import secrets

print("\n=================================")
print(" Welcome To Multi-Utility Toolkit")
print("=================================")
while True:     #LOOP CONTINUE WHILE TRUE

    print("===============================================")
    print("  ***   Chose an option:")
    print("-----------------------------------------------")
    print("   1. Datetime and Time Operations")
    print("   2. Methemetical Operations")                        #OPSTIONS
    print("   3. Random Date Generation")
    print("   4. Generate Unique Identifiers (UUID)")
    print("   5. File Operations (Custom Module)")
    print("   6. Explore Module Attributes (dir())")
    print("   7. Exit")
    print("===============================================\n")

    main_choise=int(input("Enter your choise:"))

    match main_choise:      #SWITCH CASE FOR MATCH CHOISES
    
    #CASE 1 FOR FILE SYSTEM OPERATIONS
        case 1:
            while True:
                print("\n==============================================")
                print("  ***   FILE SYSTEM OPERATIONS:")
                print("   1. Display Current Date and Time")
                print("   2. Calculate Diffrent Between Two Date/times")
                print("   3. Format Date Into Custom Formet")
                print("   4. Stopwatch")
                print("   5. Countdown Timer")           
                print("   6. Back To Main Menu\n")

                File_choise=int(input("Enter Your Choise:"))
                match File_choise:
                # show current date and time
                    case 1:
                        print(datetime.now().strftime("Current date: %Y-%m-%d || and Time: %H:%M:%S"))
                        
                #calculate diffrent between two dates 
                    case 2:
                        string1=input("Enter The First Date(YYYY-MM-DD):")
                        string2=input("Enter The second Date(YYYY-MM-DD):")

                        date1=datetime.strptime(string1,"%Y-%m-%d")
                        date2=datetime.strptime(string2,"%Y-%m-%d")

                        Difference=(date2-date1).days
                        print(f"Difference:{Difference} days")
                        
                #Formet date into custom formet
                    case 3:

                        string=input("Enter date (YYYY-MM-DD)")

                        date=datetime.strptime(string,"%Y-%m-%d")       #convert to date
                        print("Chose An Option:")
                        print("1. MM-DD-YYYY")
                        print("2. DD-MM-YYYY")
                        print("3. YYYY-DD-MM")
                        choise_date=int(input("Enter your choise"))

                        if choise_date==1:      #mm-dd-yyyy
                            print("\n................")
                            print("  *. MM-DD-YYYY")
                            print(datetime.strftime(date,"Date:%m-%d-%Y"))

                        elif choise_date==2:    #dd-mm-yyyy
                            print("\n................")
                            print("  *. DD-MM-YYYY")
                            print(datetime.strftime(date,"Date:%d-%m-%Y"))

                        elif choise_date==3:    #yyyy-dd-mm
                            print("\n................")
                            print("  *. YYYY-DD-MM")
                            print(datetime.strftime(date,"Date:%Y-%d-%m"))

                        else:
                            print("Invelid choise...")
                        

                #stopwatch
                    case 4:
                    
                        while True:
                            print("Enter your choise:")
                            print("1. Start")
                            print("2. Stop")
                            choise=int(input("Enter your choise:"))

                            if choise==1:       #starting....
                                start=datetime.now()
                                print("Start Time:",start.strftime("[%m/%d/%Y, %H:%M:%S]"))
                                print("Starting....\n")

                            elif choise==2:     #Ending....
                                end=datetime.now()
                                print("End Time:",end.strftime("[%m/%d/%Y, %H:%M:%S]"))
                                print("Ending....\n")

                                result=end-start    #Diffrent calculation
                                print("Diffrent Time:",result,"\n")
                                break

                            else:
                                print("Invelid Choise...")
    
                #Countdown timer
                    case 5:
                        import time
                        seconds=int(input("Enter time for Countdown timer in Secodes:"))

                        while seconds>=0:        #countdown time using time.sleep(1-second)
                           print(f"Time left:{seconds} seconds",end="\r")
                           time.sleep(1)
                           seconds-=1

                        print("\nTime's up!")
                       
                    case 6:
                        break
                       
                    case _:
                        print("Invelid choise.....")

    #CASE 2 FOR METHMETICAL OPERATTION
        case 2:
            while True:
                print("\n_______________________________")
                print("  ***   METHMETICAL OPERTIONS:")
                print("   1. Calculate Fectorial")
                print("   2. Solve Compound Interest")                  #opstions
                print("   3. Trigonometric Calculation")
                print("   4. Area of Geometric Shapes")
                print("   5. Back To Main Menu\n")

                math_choise=int(input("Enter Your Choise:"))
                match math_choise:
                # find fectorial
                    case 1:
                       
                       number=int(input("Enter Number For Find Fectorial:"))
                       print(f"Fectorial Of {number} is: {math.factorial(number)}")
                        
                #Solve compound interest
                    case 2:
                        def calculator(amt,rt,tm):
                            intrest=(amt*(1+(rt/100))**tm)      #formula of calculate interest
                            return intrest

                        amount=float(input("Enter Principal Amount:"))
                        interest_rate=float(input("Enter Rate of Interest (in %):"))
                        timeline=float(input("Enter time (in year):"))

                        total_interest=calculator(amount,interest_rate,timeline)        #function to calculte interest

                        print(f"\n Compound interest :{total_interest}")


                #Trigonometric calculation
                    case 3:

                        degree=int(input("Enter value For Trigonometric calculation (in Degree):"))

                        print("Trigometric Calculation:")
                        dg=math.radians(degree)
                        print(f"Sin({degree}°): {math.sin(dg):.2f}")
                        print(f"Cos({degree}°): {math.cos(dg):.2f}")
                        print(f"Ten({degree}°): {math.tan(dg):.2f}")
                        

                #Area of geometric shapes
                    case 4:
                            print("Enter your choise:")
                            print("1. Circle")
                            print("2. Square")
                            print("3. Triangle")
                            print("4. rectengle")

                            choise=int(input("Enter your choise:"))

                            if choise==1:               #circle
                                print(" * Circle:\n")
                                redious=float(input("Enter redious :"))
                                area=math.pi*(redious**2)
                                print(f"Area of Circle : {area:.2f}")

                            elif choise==2:             #square
                                print(" * Square:\n")
                                side=float(input("Enter side for Square:"))
                                area=side*side
                                print(f"Area of Square :{area:.2f}")

                            elif choise==3:             #triangle
                                print(" * triangle:\n")
                                height=float(input("Enter hight of triangle:"))
                                base=float(input("Enter base of triangle:"))
                                area=(height*base)/2
                                print(f"Area of triangle :{area:.2f}")

                            elif choise==4:             #rectengle
                                print(" * Rectangle:\n")
                                length=float(input("Enter Length of Rectangle:"))
                                width=float(input("Enter Width Rectangle:"))
                                area=length*width
                                print(f"Area of triangle :{area:.2f}")

                            else:
                                print("Invelid Choise...")
                       
                    case 5:
                        break
                       
                    case _:
                        print("Invelid choise.....")

    #CASE 3 FOR RANDOM DATA GENERATOR
        case 3:
            while True:
                print("\n_______________________________")
                print("  ***  RANDOM DATA OPERATIONS:")
                print("   1. Generate a Random Number")
                print("   2. Generate Ramdom List")
                print("   3. Create random Password")
                print("   4. Generate Random OTP")
                print("   5. Back To Main Menu\n")

                data_choise=int(input("Enter Your Choise:"))
                match data_choise:
                # Generate random Number
                    case 1:
                       print(f"Rendom Number (1-100): {random.randint(1,100)}")
                        
                #Generate Random List
                    case 2:
                       my_list=["C","C++","Python","pandas","Num-py","Power-BI","Algorithms","Mathemetics"]

                       print(f" My list: {my_list}\n") 
                       print(f" '{random.choice(my_list)}' usde in AIML & Data Science")
 
                #Generate random Password
                    case 3:
                        print("Password Generator:")
                        def password(len=8):

                            All_data=string.ascii_letters+string.digits+string.punctuation
                            password=''.join(random.choice(All_data) for _ in range(len)) 
                                                                             #random choise take date from all data in length 8
                            print(f"random Password: {password}")
                            
                        password()


                #Generate random OTP
                    case 4:
                            print(" OTP Generator:")
                            def otp_generator(len=6):

                                All_data=string.digits
                                otp=''.join(secrets.choice(All_data) for _ in range(len))
                                                                        #random choise take digit from all data in length 6
                                print(f"random OTP: {otp}")
                                
                            otp_generator()

                    case 5:
                        break
                       
                    case _:
                        print("Invelid choise.....")

    #CASE 4 Generte  Unique Indetifirers
        case 4:
            while True:
                print("\n_______________________________")
                print("  ***  GENERATE UNIQUE IDENTIFIERS:")
                print("   1. Generate UUID1(based on timestemp and MAC address)")
                print("   2. Generate UUID4(Random UUID)")
                print("   3. Back To Main Menu\n")

                uuid_choise=int(input("Enter Your Choise:"))
                match uuid_choise:
                #Generate uuid based on mac address and timestemp
                    case 1:
                       print("  based on timestemp and MAC address")
                       print(f"Generated UUID1: {uuid.uuid1()}")
                        
                #Generate random uuid
                    case 2:
                       print("  Random UUID")
                       print(f"Generated UUID4: {uuid.uuid4()}")

                    case 3:
                        break
                       
                    case _:
                        print("Invelid choise.....")

    #CASE 5 FOR FILE OPERATION
        case 5:
            while True:
                print("\n_______________________________")
                print("  ***  FILE OPERATIONS:")
                print("   1. Create a file")
                print("   2. Write To a File")
                print("   3. Read From a File")
                print("   4. Append To a File")
                print("   5. Back To Main Menu\n")

                File_choise=int(input("Enter Your Choise:"))
                match File_choise:
                # Create new file
                    case 1:
                        try:
                            filename=input("Enter File name to create file:")

                            file=open(filename,"a")     #file create with append mode
                            file.close()
                            print(f"File '{filename}' created Successfully...")
                        
                        except Exception:
                            raise print("Error: File not created, Please try Again....")

                        
                #Write in file
                    case 2:
                        list=os.listdir(os.getcwd())        #list of files
                        print("-------------------------------------")
                        print("  List Of Files In Current Directory:")
                        print("-------------------------------------")
                        for files in list:
                            print(f" - {files}")
                        print("-------------------------------------")

                       
                        filename=input("Enter File name to Write in file:")
                        if os.path.exists(filename):
                            file=open(filename,"w")         #open in write mode
                            str=input("Enter Text to Write in File:")
                            file.write(str)                 #write text in file
                            file.close()
                            print(f"File '{filename}' Written Successfully...")

                        else:
                            print("Error: File not found, Please try Again....")    #error when file not found
                        
                #Read file
                    case 3:
                        try:
                            filename=input("Enter File Name to Read File:")

                            file=open(filename,"r")     #file open with read mode
                            print("Read File:")
                            print(file.read())          #File read
                        except FileNotFoundError:
                            print("Error: File not found in current directory")

                #append text in file
                    case 4:
                        list=os.listdir(os.getcwd())            #list of all files
                        print("-------------------------------------")
                        print("  List Of Files In Current Directory:")
                        print("-------------------------------------")
                        for files in list:
                            print(f" - {files}")
                        print("-------------------------------------")

                       
                        filename=input("Enter File name to Write in file:")
                        if os.path.exists(filename):
                            file=open(filename,"+a")        #file open in append mode
                            str=input("Enter Text to Write in File:")
                            file.write(str)                 #text append in file
                            file.close()
                            print(f"File '{filename}' append Successfully...")

                        else:
                            print("Error: File not found, Please try Again....")

                    case 5:
                        break
                       
                    case _:
                        print("Invelid choise.....")

    #CASE 6 FOR ATTRIBUTES OF MPDULES
        case 6:
            try:
                mod=input("Enter Module Attributes:")
                attributes=dir(__import__(mod))     # directory of attributes of modele
                print(f"Module : {mod} \n List: {attributes}") 

            except ImportError:             #give import error
                print(f"'{mod}' Module Not Found..")

    #CASE 7 FOR BREAK
        case 7:
            break
