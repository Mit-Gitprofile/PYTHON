# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time

search="python tutorial"

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
driver.get(f"https://www.wikipedia.org/")
time.sleep(2)


elem = driver.find_element(By.ID,"searchInput")
time.sleep(2)

elem = driver.find_element(By.ID,"searchInput")
elem.send_keys(search)
time.sleep(2)

elem = driver.find_element(By.ID,"searchInput")
elem.send_keys(Keys.RETURN)
time.sleep(2)



import requests
from bs4 import BeautifulSoup
import pandas as pd

Title=[]
Link=[]

url="https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1"

request=requests.get(url)
# print(request.status_code)

soup=BeautifulSoup(request.text,"html.parser")



title=soup.find_all("div",class_="mw-search-result-heading")

for i in title:
    tt=i.text
    Title.append(tt)

for i in Title:
    print(i)


links=soup.find_all("div",class_="mw-search-result-heading")

for i in links:
    link=i.a['href'] 
    final=url+link
    Link.append(final)

for i in Link:
    print(i)

print(len(Title))
print(len(Link))


driver.quit()
# Out:
# Python (programming language)
# Python syntax and semantics
# Python Package Index
# Genetic algorithm (section Tutorials)
# Tkinter (category Python (programming language) libraries)
# Metasyntactic variable (section Python)
# Python Imaging Library
# Coding conventions
# Anaconda (Python distribution)
# List comprehension (redirect from Python comprehension)
# Namespace (section Python)
# PythonAnywhere
# Standard library
# String interpolation (section Python)
# Zachary's karate club
# "Hello, World!" program
# Pygame (category Free software programmed in Python)
# Class (computer programming)
# Comparison of integrated development environments (redirect from List of integrated development environments for Python)
# Python Conference
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Python_(programming_language)
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Python_syntax_and_semantics
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Python_Package_Index
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Genetic_algorithm
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Tkinter
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Metasyntactic_variable
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Python_Imaging_Library
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Coding_conventions
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Anaconda_(Python_distribution)
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/List_comprehension
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Namespace
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/PythonAnywhere
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Standard_library
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/String_interpolation
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Zachary%27s_karate_club
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/%22Hello,_World!%22_program
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Pygame
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Class_(computer_programming)
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Comparison_of_integrated_development_environments
# https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1/wiki/Python_Conference
# 20
# 20

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

Title=[]
Link=[]

url="https://en.wikipedia.org/wiki/Special:Search?go=Go&search=python+tutorial&ns0=1"

request=requests.get(url)
# print(request.status_code)

soup=BeautifulSoup(request.text,"html.parser")



title=soup.find_all("div",class_="mw-search-result-heading")

for i in title:
    tt=i.text
    Title.append(tt)

for i in Title:
    print(i)


links=soup.find_all("div",class_="mw-search-result-heading")

for i in links:
    link=i.a['href'] 
    final=url+link
    Link.append(final)

for i in Link:
    print(i)

print(len(Title))
print(len(Link))

# dataframe=pd.DataFrame({"Title":Title,"Links":Link})
# print(dataframe)

# dataframe.to_csv("Title_link.csv")
