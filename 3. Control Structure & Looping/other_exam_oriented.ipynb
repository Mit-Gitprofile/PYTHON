# %%
#other exam oriented programms

#QUE-1
#1. Python Program to Check if a Number is Positive, Negative or 0.

num=int(input("Enter any number:"))

if num==0:
    print("Number is zero:",num)

elif num<0:
    print("number is negative:",num)

else:
    print("Number is positive:",num)

# %%
#QUE-2
#2. Python Program to Check if a Number is Odd or Even.

num=int(input("Enter any number:"))

if num==0:
    print("number is zero:",num)

elif num%2==1:
    print("Number is odd:",num)

elif num%2==0:
    print("number is even:",num)

else:
    print("not is number:")

# %%
#QUE-3
#3. Python Program to Check Leap Year.

year=int(input("Enter year to check:"))

if((year%4==0 and year%100!=0) or year%400==0):
    print(year,"is leap year")

else:
    print(year,"is not leap year")

# %%
#QUE-4
#4. Python Program to Find the Largest Among Three Numbers.

n1=int(input("Enter first number:"))
n2=int(input("Enter second number:"))
n3=int(input("Enter third number:"))

print("Number is:",n1,n2,n3)

if n1>n2:
    if(n1>n3):
        print(n1,"First Number is Largest Among Three Numbers.")
    else:
        print(n3,"Third Number is Largest Among Three Numbers.")
else:
    if(n2>n3):
        print(n2,"Second Number is Largest Among Three Numbers.")
    else:
        print(n3,"Third Number is Largest Among Three Numbers.")

# %%
#QUE-5
#5. Python Program to Find the Factorial of a Number.

num=int(input("Enter the number to find the fectorial:"))
fect=1

for x in range(1,num+1):
    #print(x)
    fect=fect*x
    
print("Fectorial of",num,"is",fect)

# %%
#QUE-6
#6. Python Program to Display the multiplication Table.

num=int(input("Enter number for multiplication of table:"))

print("Table of:",num,"\n")
for i in range(1,11):
    print(num,"x",i,"=",num*i)

# %%
#QUE-7
#7. Python Program to Print the Fibonacci sequence.

num=int(input("Enter the number for fibinacci series:"))
a=0
b=1

print(a)
print(b)

for i in range(2,num+1):
    c=a+b
    print(c)
    a=b
    b=c

# %% [markdown]
# 1->in armstrong number first we value store in another variable like temp
# 2->after take while loop for number is greater then 0
# 3->digit for temp%10 and temp//=10 for reverce the number
# 4->sum for sum the digit*digit*digit (digit**3)
# 5-> num == sum number is armstrong

# %%
#QUE-8
#8. Python Program to Check Armstrong Number.

num=int(input("Enter the number for checking armstrong number:"))

temp=num
sum=0

while temp>0:
    digit=temp%10
    sum+=digit**3
    temp//=10
    
if num==sum:
   print(num,"is an armstrong number")
else:
   print(num,"is not an armstrong number")

# %%
#QUE-9
#9. Python Program to find those numbers which are divisible by 7 and multiple of 5, 
# between 1500 and 2700 (both included).

for number in range(1500,2701):
    if number%7==0 and number%5==0:
        print(number)

# list=[number for number in range(1500,2701) if (number%7==0 and number%5==0)]
# print(list)

# %%
#QUE-10
#10. Python Program to construct the following pattern, using a nested for loop.

# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

for i in range(1,6):
    for j in range(1,i+1):
        print("*" , end = " ")
    print()

for i in range(4,0,-1):
    for j in range(1,i+1):
        print("*" , end = " ")
    print()

# %%
#QUE-11
#11. Python Program that prints all the numbers from 0 to 6 except 3 and 6.

for x in range(0,7):
    if x==3 or x==6:
        continue
    print(x)

# %%
#QUE-12
#12. Python Program that accepts a string and calculate the number of digits and letters.

string=input("Enter string:")

digit=0
latter=0

for x in string:
    if x.isalpha():
        latter+=1
    if x.isdigit():
        digit+=1

print("String is:",string,"\n")
print("Total latters in string =",latter)
print("Total digits in string =",digit)

# %%
#QUE-13
#13. Python Program to check the validity of password input by users.
# Validation :
# a. At least 1 letter between [a-z] and 1 letter between [A-Z].
# b. At least 1 number between [0-9].
# c. At least 1 character from [$#@].
# d. Minimum length 6 characters.
# e. Maximum length 16 characters.

password=input("Enter the password:")

length=False
lower=False
upper=False
digit=False
special_symbol=False

if 6<= len(password) <=16:
    length=True
    
    for x in password:
        if x.islower():
            lower=True
        elif x.isupper():
            upper=True
        elif x.isdigit():
            digit=True
        elif x in "$#@":
            special_symbol=True
   

if (length and lower and upper and digit and special_symbol):
    print("PASSWORD IS VELID...")
else:
    print("PASSWORD IS NOT VELID...!!!")
# Out:
# PASSWORD IS NOT VELID...!!!

# %%
#QUE-14
#14. Python Program to check whether an alphabet is a vowel or consonant.

string=input("Enter the string:")

print("String is:",string)

for i in string.lower():
    if(i=="a" or i=="e" or i=="i" or i=="o" or i=="u"):
        print("Vowels:",i)
    else:
        print("Constants:",i)

# %%
#QUE-15
#15. Python Program to convert month name to a number of days.
# Expected Output:
# List of months: January, February, March, April, May, June, July, August, September, October, November, December
# Input the name of Month: February
# No. of days: 28/29 days

month=input("Enter month name like(january/february...):")

match month.lower():
    case "january":
        print("Month : january")
        print("No. of days: 30 days")
    
    case "fabruary":
        print("Month : february")
        print("No. of days: 28/29 days")

    case "march":
        print("Month : march")
        print("No. of days: 31 days")

    case "april":
        print("Month : april")
        print("No. of days: 30 days")

    case "may":
        print("Month : may")
        print("No. of days: 31 days")

    case "june":
        print("Month : june")
        print("No. of days: 30 days")

    case "july":
        print("Month : july")
        print("No. of days: 31 days")
    
    case "auguest":
        print("Month : auguest")
        print("No. of days: 31 days")

    case "septmber":
        print("Month : septmber")
        print("No. of days: 30 days")

    case "october":
        print("Month : october")
        print("No. of days: 31 days")

    case "november":
        print("Month : november")
        print("No. of days: 30 days")

    case "december":
        print("Month : december")
        print("No. of days: 31 days")

    case _:
        print("WRONG CHOISE.....")

# %%
#QUE-16
#16. Python Program to display astrological sign for given date of birth.
# Expected Output:
# Input birthday: 15
# Input month of birth (e.g. march, july etc): may
# Your Astrological sign is : Taurus

# %%
#QUE-17
#117. Python Program to construct the following pattern, using a nested loop number.
# Expected Output:
# 1
# 22
# 333
# 4444
# 55555
# 666666
# 7777777
# 88888888
# 999999999.

for i in range(1,10):
    for j in range(1,i+1):
        print(i , end = "")
    print()
