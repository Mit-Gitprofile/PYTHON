# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time


service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
driver.get(f"https://auto.mahindra.com/suv")
time.sleep(2)

driver.save_screenshot('C://Users/HP/OneDrive/Pictures/Screenshots/screenshot_1.png')

import requests
from bs4 import BeautifulSoup
import pandas as pd

Title=[]
Link=[]

url="https://auto.mahindra.com/suv"

request=requests.get(url)
# print(request.status_code)

soup=BeautifulSoup(request.text,"html.parser")

title=soup.find_all("span",class_="contentProductSUvs m-3")

for i in title:
    tt=i.text
    Title.append(tt)

for i in Title:
    print(i)


links=soup.find_all("div",class_="buttonsSUvsPL d-flex justify-content-center")
n_url="https://auto.mahindra.com/"
for i in links:
    link=i.a['href'] 
    final=n_url+link
    Link.append(final)

for i in Link:
    print(i)

dataframe=pd.DataFrame({"Title":Title,"Links":Link})

driver.quit()
# Out:
# THAR ROXX
# ₹12.99L - ₹23.09L
#
#
# XUV 3XO
# ₹7.99L - ₹15.56L
#
#
# SCORPIO-N
# ₹13.99L - ₹24.69L
#
#
# XUV700
# ₹13.99L - ₹25.89L
#
#
# THAR
# ₹11.50L - ₹17.60L
#
#
# SCORPIO CLASSIC
# ₹13.62L - ₹17.50L
#
#
# BOLERO NEO
# ₹9.95L - ₹12.15L
#
#
# BOLERO NEO PLUS
# ₹11.39L - ₹12.49L
#
#
# BOLERO
# ₹9.79L - ₹10.91L
#
#
# XUV400
# ₹16.74L - ₹17.69L
#
#
# MARAZZO
# ₹14.59L - ₹17.00L
#
# https://auto.mahindra.com//suv/thar-roxx/TH5D.html
# https://auto.mahindra.com//suv/xuv3xo/X3XO.html
# https://auto.mahindra.com//suv/scorpio-n/SCN.html
# https://auto.mahindra.com//suv/xuv700/X700.html
# https://auto.mahindra.com//suv/thar/THRN.html
# https://auto.mahindra.com//suv/scorpio-classic/SCRC.html
# https://auto.mahindra.com//suv/bolero-neo/NEO.html
# https://auto.mahindra.com//suv/bolero-neo-plus/NEOP.html
# https://auto.mahindra.com//suv/bolero/BOL.html
# https://auto.mahindra.com//suv/xuv400/X400.html
# https://auto.mahindra.com//suv/marazzo/MRZO.html
